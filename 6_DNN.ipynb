# %% [markdown]
# # Modelo DNN

# %% [markdown]
# ### Se importan librerías necesarias

# %%
import os
# os.environ["SM_FRAMEWORK"] = "tf.keras"
import pathlib
import numpy as np
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# import seaborn as sns
import datetime as dt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense, Flatten, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
# from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
import warnings
warnings.filterwarnings("ignore")

# %%
#Conexión de google drive con el repo
from google.colab import drive
drive.mount('/content/drive')

##==========================
ruta = os.path.join("/content/drive/MyDrive","MonografiaUdeA")
os.chdir(ruta)
abspath = pathlib.Path.cwd()
print(f"Directorio de trabajo: {abspath}")
###==========================
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Directorio de trabajo: /content/drive/MyDrive/MonografiaUdeA

# %%
def parse(x):
    return dt.datetime.strptime(x, '%Y-%m-%d')
dataset = pd.read_csv(os.path.join(abspath,"datasets", "procesado", "3_dataset_filtrado.csv"), index_col=0, date_parser=parse)
df = dataset.copy()
df.head(3)
# Out:
#             precio_bolsa       demanda  disp_dec_hidraulica  disp_dec_termica  \
# fecha
# 2010-01-01    120.501228  1.133616e+08        356125.000000     121611.607143
# 2010-01-02    118.495340  1.254718e+08        353776.515152     121633.928571
# 2010-01-03    121.160145  1.211452e+08        356579.545455     119455.357143
#
#             gen_hidraulica  gen_no_termica  gen_termica  aportes_energia  \
# fecha
# 2010-01-01     35796804.67     13362226.83  66260052.96       45616100.0
# 2010-01-02     46595646.99     13393741.63  67691806.16       43097100.0
# 2010-01-03     42578875.20     13046074.83  68012828.41       43400400.0
#
#             precio_oferta      vol_util  indice_ONI  vertimientos
# fecha
# 2010-01-01     267.437633  1.000661e+10         1.5           0.0
# 2010-01-02     277.153592  9.995147e+09         1.5           0.0
# 2010-01-03     313.552755  9.992677e+09         1.5           0.0

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
scaler = MinMaxScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)
scaled_df.head(5)
# Out:
#             precio_bolsa   demanda  disp_dec_hidraulica  disp_dec_termica  \
# fecha
# 2010-01-01      0.044641  0.000000             0.654490          0.612788
# 2010-01-02      0.043589  0.120600             0.645406          0.613112
# 2010-01-03      0.044986  0.077513             0.656248          0.581456
# 2010-01-04      0.046456  0.304433             0.598374          0.540133
# 2010-01-05      0.044727  0.363560             0.615809          0.540155
#
#             gen_hidraulica  gen_no_termica  gen_termica  aportes_energia  \
# fecha
# 2010-01-01        0.000000        0.755503     0.665266         0.029498
# 2010-01-02        0.074578        0.757482     0.682814         0.025017
# 2010-01-03        0.046838        0.735654     0.686748         0.025557
# 2010-01-04        0.182635        0.742847     0.717898         0.020238
# 2010-01-05        0.230502        0.827840     0.692230         0.021626
#
#             precio_oferta  vol_util  indice_ONI  vertimientos
# fecha
# 2010-01-01       0.144822  0.484812    0.738095           0.0
# 2010-01-02       0.162552  0.483498    0.738095           0.0
# 2010-01-03       0.228976  0.483215    0.738095           0.0
# 2010-01-04       0.210667  0.480082    0.738095           0.0
# 2010-01-05       0.276509  0.475660    0.738095           0.0

# %%
scaled_df.tail(5)
# Out:
#             precio_bolsa   demanda  disp_dec_hidraulica  disp_dec_termica  \
# fecha
# 2019-12-27      0.155485  0.845458             0.110515          0.354955
# 2019-12-28      0.127943  0.784855             0.109813          0.359922
# 2019-12-29      0.110686  0.659665             0.120313          0.397399
# 2019-12-30      0.151277  0.765573             0.098931          0.432077
# 2019-12-31      0.125619  0.611236             0.119057          0.392498
#
#             gen_hidraulica  gen_no_termica  gen_termica  aportes_energia  \
# fecha
# 2019-12-27        0.616507        0.174390     0.642084         0.126770
# 2019-12-28        0.653376        0.223659     0.499929         0.092333
# 2019-12-29        0.584269        0.171299     0.473201         0.088551
# 2019-12-30        0.644047        0.237375     0.494649         0.145244
# 2019-12-31        0.538956        0.200925     0.488179         0.246500
#
#             precio_oferta  vol_util  indice_ONI  vertimientos
# fecha
# 2019-12-27       0.217813  0.619055         0.5      0.000000
# 2019-12-28       0.224686  0.613493         0.5      0.000000
# 2019-12-29       0.253386  0.608943         0.5      0.000000
# 2019-12-30       0.230048  0.607142         0.5      0.000000
# 2019-12-31       0.249581  0.613121         0.5      0.065609

# %% [markdown]
# ### División de datos en entrenamiento y prueba

# %%
def create_sequences(data, n_lag, target_column):
    sequences = []
    targets = []
    for i in range(len(data) - n_lag):
        seq = data[i:i + n_lag]
        target = data[i + n_lag][target_column]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

def split_data(lags, scaled_df, train_test_split_ratio = 0.7):
  lagged_data = {}
  for lag in lags:
      X, y = create_sequences(scaled_df.values, lag, target_column=0)
      lagged_data[lag] = (X, y)

  train_test_split_ratio = train_test_split_ratio
  split_idx = int(len(scaled_df) * train_test_split_ratio)

  train_data = {lag: (X[:split_idx], y[:split_idx]) for lag, (X, y) in lagged_data.items()}
  test_data = {lag: (X[split_idx:], y[split_idx:]) for lag, (X, y) in lagged_data.items()}

  # lagged_data_no_var = {}
  # for lag in retardos:
  #     X, y = create_sequences(scaled_df.drop(columns=['precio_bolsa']).values, lag, target_column=0)
  #     lagged_data_no_var[lag] = (X, y)

  # train_data_no_var = {lag: (X[:split_idx], y[:split_idx]) for lag, (X, y) in lagged_data_no_var.items()}
  # test_data_no_var = {lag: (X[split_idx:], y[split_idx:]) for lag, (X, y) in lagged_data_no_var.items()}

  return train_data, test_data#, train_data_no_var, test_data_no_var

def get_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    return mae, mse, mape, rmse

# %%
def create_model(model_type, input_shape, elements_to_predict, optimizer, loss, neuronas = 20):

    model = Sequential()
    if model_type == 'RNN':
        model.add(SimpleRNN(neuronas, input_shape=input_shape))
        model.add(Flatten())
        model.add(Dropout(0.3))
        model.add(Dense(20, activation='relu'))
        model.add(Dropout(0.3))

    elif model_type == 'DNN':
        model.add(Dense(neuronas, input_shape=input_shape))
        model.add(Flatten())
        model.add(Dropout(0.3))
        model.add(Dense(20, activation='relu'))
        model.add(Dropout(0.3))

    elif model_type == 'LSTM':
        model.add(LSTM(neuronas, input_shape=input_shape))
        model.add(Flatten())
        model.add(Dropout(0.3))
        model.add(Dense(20, activation='relu'))
        model.add(Dropout(0.3))

    elif model_type == 'GRU':
        model.add(GRU(neuronas, input_shape=input_shape))
        model.add(Flatten())
        model.add(Dropout(0.3))
        model.add(Dense(20, activation='relu'))
        model.add(Dropout(0.3))

    model.add(Dense(1))
    model.compile(optimizer = optimizer, loss = loss)
    print(f"Model {model_type} created. Params -> input_shape: {input_shape}, elements_to_predict: {elements_to_predict}, optimizer: {optimizer}, loss: {loss}")
    return model

# %%
retardos = [60, 70, 80]
neurons = [25, 50, 100]
modelos_implementar = ['DNN']
metricas = ['MAE', 'MAPE', 'MSE', 'RMSE']
elementos_a_predecir = [30]
optimizers = ['adam']
losses = ['mse']
epochs = [20, 30, 40]
batch_size = [32, 64]

# %%
# retardos = [60]
# neurons = [25]
# modelos_implementar = ['DNN']
# metricas = ['MAE', 'MAPE', 'MSE', 'RMSE']
# elementos_a_predecir = [30]
# optimizers = ['adam']
# losses = ['mse']
# epochs = [30]
# batch_size = [32]

# %%
train_data, test_data = split_data(lags = retardos, scaled_df = scaled_df, train_test_split_ratio = 0.8)

# %%
for retardo in retardos:
    print("retardo",retardo, "dimensiones",train_data[retardo][0].shape, test_data[retardo][0].shape)
# Out:
# retardo 60 dimensiones (2921, 60, 12) (671, 60, 12)
# retardo 70 dimensiones (2921, 70, 12) (661, 70, 12)
# retardo 80 dimensiones (2921, 80, 12) (651, 80, 12)

# %%
#Se inicializa la semilla
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)
tf.compat.v1.set_random_seed(42)

models_with_var = {lag: {} for lag in retardos}

# %%
# Create arrays to represent parameter combinations
lag_grid, model_grid, optimizer_grid, loss_grid, element_grid, neurons_grid = np.meshgrid(retardos, modelos_implementar, optimizers, losses, elementos_a_predecir, neurons)
lag_grid = lag_grid.flatten()
model_grid = model_grid.flatten()
optimizer_grid = optimizer_grid.flatten()
loss_grid = loss_grid.flatten()
element_grid = element_grid.flatten()
neurons_grid = neurons_grid.flatten()

# %%
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error

def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

early_stopping = EarlyStopping(monitor='loss', patience = 15, restore_best_weights=True)

model_summary_df = pd.DataFrame()
index = 0
for model, lag, element_to_predict, optimizer, loss, neurons  in zip(model_grid, lag_grid, element_grid, optimizer_grid, loss_grid, neurons_grid):

    input_shape = train_data[lag][0].shape[1:]
    models_with_var[lag][model] = create_model(model, input_shape, elements_to_predict=element_to_predict, optimizer=optimizer, loss=loss, neuronas= neurons)
    for epoch in epochs:
        for batch in batch_size:
            print(f"modelo: {model}, neuronas: {neurons},lag: {lag}, elementos: {element_to_predict}, optimizador: {optimizer}, perdida: {loss}, epoch: {epoch}, batch: {batch}")
            index = index + 1
            _model = models_with_var[lag][model]
            X_train, y_train = train_data[lag]
            X_test, y_test = test_data[lag]
            history = _model.fit(
                X_train, y_train,
                epochs=epoch, batch_size=batch,
                validation_split=0.2,
                callbacks=[early_stopping],
                verbose=0
            )
            y_pred = _model.predict(X_test)
            X_train_rescaled = scaler.inverse_transform(np.hstack((X_train[:, -1, 0].reshape(-1,1),X_train[:, -1, 1:])))[:,0]
            y_pred_rescaled = scaler.inverse_transform(np.hstack((y_pred,X_test[:, -1, 1:])))[:,0]
            y_test_rescaled = scaler.inverse_transform(np.hstack((X_test[:, -1, 0].reshape(-1,1),X_test[:, -1, 1:])))[:,0]

            _model.save(os.path.join(abspath,"models","iterations",model, f'{model}_{index}.h5'))
            mse = mean_squared_error(y_test[-int(element_to_predict):], y_pred[-int(element_to_predict):])
            mae = mean_absolute_error(y_test[-int(element_to_predict):], y_pred[-int(element_to_predict):])
            rmse = mean_squared_error(y_test[-int(element_to_predict):], y_pred[-int(element_to_predict):], squared=False)
            mape = mean_absolute_percentage_error(y_test[-int(element_to_predict):], y_pred[-int(element_to_predict):])
            model_summary_df = pd.concat([model_summary_df, pd.DataFrame( {
                'id': index,
                'Modelo': model,
                'Neuronas': neurons,
                'LookBack': lag,
                'Elementos': element_to_predict,
                'Optimizador': optimizer,
                'Epocas': epoch,
                'BatchSize': batch,
                'MAE': mae,
                'MSE': mse,
                'RMSE': rmse,
                'MAPE': mape,
            }, index = [index])] )
# Out:
# Model DNN created. Params -> input_shape: (60, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 25,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 25,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# Model DNN created. Params -> input_shape: (60, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 50,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 50,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 50,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 50,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 50,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 50,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# Model DNN created. Params -> input_shape: (60, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 100,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 60, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 3ms/step
# Model DNN created. Params -> input_shape: (70, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 25,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 25,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 25,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# Model DNN created. Params -> input_shape: (70, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 50,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 50,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 50,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 50,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 50,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 50,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# Model DNN created. Params -> input_shape: (70, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 100,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 5ms/step
# modelo: DNN, neuronas: 100,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 100,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 70, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 3ms/step
# Model DNN created. Params -> input_shape: (80, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 25,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 25,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 25,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 25,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 25,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# Model DNN created. Params -> input_shape: (80, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 50,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 50,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 50,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 50,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 2ms/step
# modelo: DNN, neuronas: 50,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 5ms/step
# modelo: DNN, neuronas: 50,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 3ms/step
# Model DNN created. Params -> input_shape: (80, 12), elements_to_predict: 30, optimizer: adam, loss: mse
# modelo: DNN, neuronas: 100,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 32
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 100,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 20, batch: 64
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 100,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 30, batch: 64
# 21/21 [==============================] - 0s 4ms/step
# modelo: DNN, neuronas: 100,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 32
# 21/21 [==============================] - 0s 3ms/step
# modelo: DNN, neuronas: 100,lag: 80, elementos: 30, optimizador: adam, perdida: mse, epoch: 40, batch: 64
# 21/21 [==============================] - 0s 4ms/step

# %%
model_summary_df.to_csv(os.path.join(abspath,"models", "results",f"6_{modelos_implementar[0]}_model_results.csv"))
model_summary_df.head()
# Out:
#    id Modelo  Neuronas  LookBack  Elementos Optimizador  Epocas  BatchSize  \
# 1   1    DNN        25        60         30        adam      20         32
# 2   2    DNN        25        60         30        adam      20         64
# 3   3    DNN        25        60         30        adam      30         32
# 4   4    DNN        25        60         30        adam      30         64
# 5   5    DNN        25        60         30        adam      40         32
#
#         MAE       MSE      RMSE       MAPE
# 1  0.022562  0.000713  0.026704  17.605674
# 2  0.033925  0.001529  0.039108  23.212840
# 3  0.031332  0.001260  0.035492  23.838905
# 4  0.033834  0.001437  0.037905  22.881682
# 5  0.034452  0.001544  0.039296  23.974179

# %%
best_model = model_summary_df[model_summary_df['MSE'] == model_summary_df['MSE'].min()]
best_model
# Out:
#     id Modelo  Neuronas  LookBack  Elementos Optimizador  Epocas  BatchSize  \
# 26  26    DNN        50        70         30        adam      20         64
#
#          MAE       MSE      RMSE      MAPE
# 26  0.020776  0.000648  0.025452  15.61031

# %% [markdown]
# ### Se carga el mejor modelo

# %%
best_model_saved =load_model(os.path.join(abspath,"models","iterations",f'{modelos_implementar[0]}', f'{modelos_implementar[0]}_{best_model["id"].values[0]}.h5'))
best_model_saved.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 70, 50)            650
#
#  flatten_4 (Flatten)         (None, 3500)              0
#
#  dropout_8 (Dropout)         (None, 3500)              0
#
#  dense_13 (Dense)            (None, 20)                70020
#
#  dropout_9 (Dropout)         (None, 20)                0
#
#  dense_14 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 70691 (276.14 KB)
# Trainable params: 70691 (276.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X_train, y_train = train_data[best_model["LookBack"].values[0]]
X_test, y_test = test_data[best_model["LookBack"].values[0]]

# %% [markdown]
# ### Predicciones con el mejor modelo

# %%
 y_pred = best_model_saved.predict(X_test)
X_train_rescaled = scaler.inverse_transform(np.hstack((X_train[:, -1, 0].reshape(-1,1),X_train[:, -1, 1:])))[:,0]
y_pred_rescaled = scaler.inverse_transform(np.hstack((y_pred,X_test[:, -1, 1:])))[:,0]
y_test_rescaled = scaler.inverse_transform(np.hstack((X_test[:, -1, 0].reshape(-1,1),X_test[:, -1, 1:])))[:,0]
# Out:
# 21/21 [==============================] - 0s 3ms/step

# %%
plt.figure(figsize=(17,8))
plt.plot(X_train_rescaled, label='Train', color='blue')
plt.plot(np.arange(len(X_train_rescaled), len(X_train_rescaled) + len(y_test_rescaled)), y_test_rescaled, label='Test', color='orange')
plt.plot(np.arange(len(X_train_rescaled), len(X_train_rescaled) + len(y_pred_rescaled)), y_pred_rescaled, label='Prediction', color='green')
plt.xlabel('Observation')
plt.ylabel('Price')
plt.legend()
plt.show()

plt.figure(figsize=(17,8))
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')

plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
index = dataset.iloc[dataset.shape[0] - len(y_test_rescaled):, 0].index
predictions_df = pd.DataFrame(data = {'Precio de Bolsa Original': y_test_rescaled, 'Precio de Bolsa Predicho': y_pred_rescaled}, index = index)
predictions_df = predictions_df.iloc[-31: , :]
predictions_df.to_csv(os.path.join(abspath,"models", "results",f"6_{modelos_implementar[0]}_prediction.csv"))
predictions_df
# Out:
#             Precio de Bolsa Original  Precio de Bolsa Predicho
# fecha
# 2019-12-01                249.978260                229.333198
# 2019-12-02                217.336295                244.762973
# 2019-12-03                271.575618                253.832821
# 2019-12-04                271.912097                262.070501
# 2019-12-05                269.907110                257.267236
# 2019-12-06                223.981190                259.773062
# 2019-12-07                257.714490                253.373970
# 2019-12-08                260.535417                262.522375
# 2019-12-09                266.723857                269.131175
# 2019-12-10                305.126657                273.205656
# 2019-12-11                332.933313                279.763866
# 2019-12-12                358.685980                272.798319
# 2019-12-13                359.169273                282.709075
# 2019-12-14                382.981143                280.673468
# 2019-12-15                373.365173                284.910464
# 2019-12-16                347.505760                294.006971
# 2019-12-17                355.179513                288.052520
# 2019-12-18                307.625513                298.147191
# 2019-12-19                314.142893                290.266954
# 2019-12-20                367.008023                294.591488
# 2019-12-21                320.089987                293.512266
# 2019-12-22                337.263530                296.829058
# 2019-12-23                338.309047                298.897292
# 2019-12-24                351.480130                299.302299
# 2019-12-25                312.589853                314.897586
# 2019-12-26                275.691717                312.083600
# 2019-12-27                328.319732                314.215811
# 2019-12-28                331.918402                313.729575
# 2019-12-29                279.387930                316.407792
# 2019-12-30                246.472593                318.406706
# 2019-12-31                323.892900                314.751528
